# %%
import sys
import os
import ablift as bt


Test = bt.bayesTest()


Test.conversion_rate_prior(alpha=2, beta=25)
Test.revenue_prior(alpha=2, beta=15)

Test.add(visitors=100_000, successes=4000, revenue=100_000.00, control=True, name="Control")
Test.add(visitors=100_000, successes=4100, revenue=100_500.00, name="V1")
# Test.add(visitors=1000, successes=20, revenue=198.00,
#         name='V2')
Test.infer(samples=10_000)
Test.summary()
